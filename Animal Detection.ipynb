# %%
pip install ultralytics
# Out:
# Collecting ultralytics
#   Using cached ultralytics-8.4.40-py3-none-any.whl.metadata (39 kB)
# Requirement already satisfied: numpy>=1.23.0 in c:\users\h p\anaconda3\lib\site-packages (from ultralytics) (2.4.2)
# Requirement already satisfied: matplotlib>=3.3.0 in c:\users\h p\anaconda3\lib\site-packages (from ultralytics) (3.10.8)
# Requirement already satisfied: opencv-python>=4.6.0 in c:\users\h p\anaconda3\lib\site-packages (from ultralytics) (4.13.0.92)
# Requirement already satisfied: pillow>=7.1.2 in c:\users\h p\anaconda3\lib\site-packages (from ultralytics) (11.1.0)
# Requirement already satisfied: pyyaml>=5.3.1 in c:\users\h p\anaconda3\lib\site-packages (from ultralytics) (6.0.2)
# Requirement already satisfied: requests>=2.23.0 in c:\users\h p\anaconda3\lib\site-packages (from ultralytics) (2.32.3)
# Requirement already satisfied: scipy>=1.4.1 in c:\users\h p\anaconda3\lib\site-packages (from ultralytics) (1.17.1)
# Collecting torch>=1.8.0 (from ultralytics)
#   Using cached torch-2.11.0-cp313-cp313-win_amd64.whl.metadata (29 kB)
# Collecting torchvision>=0.9.0 (from ultralytics)
#   Using cached torchvision-0.26.0-cp313-cp313-win_amd64.whl.metadata (5.5 kB)
# Requirement already satisfied: psutil>=5.8.0 in c:\users\h p\anaconda3\lib\site-packages (from ultralytics) (5.9.0)
# Collecting polars>=0.20.0 (from ultralytics)
#   Using cached polars-1.40.0-py3-none-any.whl.metadata (10 kB)
# Collecting ultralytics-thop>=2.0.18 (from ultralytics)
#   Using cached ultralytics_thop-2.0.18-py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\h p\anaconda3\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\h p\anaconda3\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\h p\anaconda3\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (4.55.3)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\h p\anaconda3\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in c:\users\h p\anaconda3\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (24.2)
# Requirement already satisfied: pyparsing>=3 in c:\users\h p\anaconda3\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (3.2.0)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\h p\anaconda3\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (2.9.0.post0)
# Collecting polars-runtime-32==1.40.0 (from polars>=0.20.0->ultralytics)
#   Using cached polars_runtime_32-1.40.0-cp310-abi3-win_amd64.whl.metadata (1.5 kB)
# Requirement already satisfied: six>=1.5 in c:\users\h p\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib>=3.3.0->ultralytics) (1.17.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\h p\anaconda3\lib\site-packages (from requests>=2.23.0->ultralytics) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\h p\anaconda3\lib\site-packages (from requests>=2.23.0->ultralytics) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\h p\anaconda3\lib\site-packages (from requests>=2.23.0->ultralytics) (1.26.20)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\h p\anaconda3\lib\site-packages (from requests>=2.23.0->ultralytics) (2025.8.3)
# Requirement already satisfied: filelock in c:\users\h p\anaconda3\lib\site-packages (from torch>=1.8.0->ultralytics) (3.17.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in c:\users\h p\anaconda3\lib\site-packages (from torch>=1.8.0->ultralytics) (4.15.0)
# Requirement already satisfied: setuptools<82 in c:\users\h p\anaconda3\lib\site-packages (from torch>=1.8.0->ultralytics) (72.1.0)
# Requirement already satisfied: sympy>=1.13.3 in c:\users\h p\anaconda3\lib\site-packages (from torch>=1.8.0->ultralytics) (1.13.3)
# Requirement already satisfied: networkx>=2.5.1 in c:\users\h p\anaconda3\lib\site-packages (from torch>=1.8.0->ultralytics) (3.4.2)
# Requirement already satisfied: jinja2 in c:\users\h p\anaconda3\lib\site-packages (from torch>=1.8.0->ultralytics) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in c:\users\h p\anaconda3\lib\site-packages (from torch>=1.8.0->ultralytics) (2025.3.2)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\h p\anaconda3\lib\site-packages (from sympy>=1.13.3->torch>=1.8.0->ultralytics) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\h p\anaconda3\lib\site-packages (from jinja2->torch>=1.8.0->ultralytics) (3.0.2)
# Using cached ultralytics-8.4.40-py3-none-any.whl (1.2 MB)
# Using cached polars-1.40.0-py3-none-any.whl (828 kB)
# Using cached polars_runtime_32-1.40.0-cp310-abi3-win_amd64.whl (51.8 MB)
# Using cached torch-2.11.0-cp313-cp313-win_amd64.whl (114.6 MB)
# Using cached torchvision-0.26.0-cp313-cp313-win_amd64.whl (4.3 MB)
# Using cached ultralytics_thop-2.0.18-py3-none-any.whl (28 kB)
# Installing collected packages: polars-runtime-32, torch, polars, ultralytics-thop, torchvision, ultralytics
#
#    ---------------------------------------- 0/6 [polars-runtime-32]
#    ---------------------------------------- 0/6 [polars-runtime-32]
#    ---------------------------------------- 0/6 [polars-runtime-32]
#    ---------------------------------------- 0/6 [polars-runtime-32]
#    ---------------------------------------- 0/6 [polars-runtime-32]
#    ---------------------------------------- 0/6 [polars-runtime-32]
#    ---------------------------------------- 0/6 [polars-runtime-32]
#    ---------------------------------------- 0/6 [polars-runtime-32]
#    ---------------------------------------- 0/6 [polars-runtime-32]
#    ---------------------------------------- 0/6 [polars-runtime-32]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------------- -------------------------- 2/6 [polars]
#    ------------- -------------------------- 2/6 [polars]
#    ------------- -------------------------- 2/6 [polars]
#    ------------- -------------------------- 2/6 [polars]
#    ------------- -------------------------- 2/6 [polars]
#    ------------- -------------------------- 2/6 [polars]
#    ------------- -------------------------- 2/6 [polars]
#    ------------- -------------------------- 2/6 [polars]
#    ------------- -------------------------- 2/6 [polars]
#    ------------- -------------------------- 2/6 [polars]
#    ------------- -------------------------- 2/6 [polars]
#    ------------- -------------------------- 2/6 [polars]
#    ------------- -------------------------- 2/6 [polars]
#    ------------- -------------------------- 2/6 [polars]
#    ------------- -------------------------- 2/6 [polars]
#    ------------- -------------------------- 2/6 [polars]
#    ------------- -------------------------- 2/6 [polars]
#    ------------- -------------------------- 2/6 [polars]
#    ------------- -------------------------- 2/6 [polars]
#    -------------------- ------------------- 3/6 [ultralytics-thop]
#    -------------------------- ------------- 4/6 [torchvision]
#    -------------------------- ------------- 4/6 [torchvision]
#    -------------------------- ------------- 4/6 [torchvision]
#    -------------------------- ------------- 4/6 [torchvision]
#    -------------------------- ------------- 4/6 [torchvision]
#    -------------------------- ------------- 4/6 [torchvision]
#    -------------------------- ------------- 4/6 [torchvision]
#    -------------------------- ------------- 4/6 [torchvision]
#    -------------------------- ------------- 4/6 [torchvision]
#    -------------------------- ------------- 4/6 [torchvision]
#    -------------------------- ------------- 4/6 [torchvision]
#    -------------------------- ------------- 4/6 [torchvision]
#    -------------------------- ------------- 4/6 [torchvision]
#    -------------------------- ------------- 4/6 [torchvision]
#    -------------------------- ------------- 4/6 [torchvision]
#    -------------------------- ------------- 4/6 [torchvision]
#    -------------------------- ------------- 4/6 [torchvision]
#    -------------------------- ------------- 4/6 [torchvision]
#    -------------------------- ------------- 4/6 [torchvision]
#    -------------------------- ------------- 4/6 [torchvision]
#    -------------------------- ------------- 4/6 [torchvision]
#    -------------------------- ------------- 4/6 [torchvision]
#    --------------------------------- ------ 5/6 [ultralytics]
#    --------------------------------- ------ 5/6 [ultralytics]
#    --------------------------------- ------ 5/6 [ultralytics]
#    --------------------------------- ------ 5/6 [ultralytics]
#    --------------------------------- ------ 5/6 [ultralytics]
#    --------------------------------- ------ 5/6 [ultralytics]
#    --------------------------------- ------ 5/6 [ultralytics]
#    --------------------------------- ------ 5/6 [ultralytics]
#    --------------------------------- ------ 5/6 [ultralytics]
#    --------------------------------- ------ 5/6 [ultralytics]
#    --------------------------------- ------ 5/6 [ultralytics]
#    --------------------------------- ------ 5/6 [ultralytics]
#    --------------------------------- ------ 5/6 [ultralytics]
#    --------------------------------- ------ 5/6 [ultralytics]
#    --------------------------------- ------ 5/6 [ultralytics]
#    --------------------------------- ------ 5/6 [ultralytics]
#    --------------------------------- ------ 5/6 [ultralytics]
#    --------------------------------- ------ 5/6 [ultralytics]
#    --------------------------------- ------ 5/6 [ultralytics]
#    --------------------------------- ------ 5/6 [ultralytics]
#    --------------------------------- ------ 5/6 [ultralytics]
#    --------------------------------- ------ 5/6 [ultralytics]
#    --------------------------------- ------ 5/6 [ultralytics]
#    --------------------------------- ------ 5/6 [ultralytics]
#    --------------------------------- ------ 5/6 [ultralytics]
#    --------------------------------- ------ 5/6 [ultralytics]
#    ---------------------------------------- 6/6 [ultralytics]
#
# Successfully installed polars-1.40.0 polars-runtime-32-1.40.0 torch-2.11.0 torchvision-0.26.0 ultralytics-8.4.40 ultralytics-thop-2.0.18
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Retrying (Retry(total=4, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='pypi.org', port=443): Read timed out. (read timeout=15)")': /simple/polars/

# %%
from ultralytics import YOLO
import cv2
import matplotlib.pyplot as plt

# %%
model = YOLO("yolov8n.pt")
# Out:
# Downloading https://github.com/ultralytics/assets/releases/download/v8.4.0/yolov8n.pt to 'yolov8n.pt': 100% ━━━━━━━━━━━━ 6.2MB 951.3KB/s 6.7s7s<0.0sss2.7s

# %%
import matplotlib.pyplot as plt

animals = ["dog", "cat", "cow", "lion"]
counts = [5, 3, 2, 4]

plt.bar(animals, counts)
plt.title("Animal Detection Count")
plt.show()

# %%
import seaborn as sns
from sklearn.metrics import confusion_matrix

y_true = ["dog", "cat", "lion", "dog"]
y_pred = ["dog", "cat", "dog", "dog"]

cm = confusion_matrix(y_true, y_pred)
sns.heatmap(cm, annot=True)
# Out:
# <Axes: >
